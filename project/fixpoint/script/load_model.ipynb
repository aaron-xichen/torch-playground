-- %%
require 'nn';
require 'loadcaffe'

-- %%
model = loadcaffe.load('/home/chenxi/modelzoo/vgg16/deploy.prototxt','/home/chenxi/modelzoo/vgg16/weights.caffemodel', 'nn')
-- Out:
-- Successfully loaded /home/chenxi/modelzoo/vgg16/weights.caffemodel
-- conv1_1: 64 3 3 3
-- conv1_2: 64 64 3 3
-- conv2_1: 128 64 3 3
-- conv2_2: 128 128 3 3
-- conv3_1: 256 128 3 3
-- conv3_2: 256 256 3 3
-- conv3_3: 256 256 3 3
-- conv4_1: 512 256 3 3
-- conv4_2: 512 512 3 3
-- conv4_3: 512 512 3 3
-- conv5_1: 512 512 3 3
-- conv5_2: 512 512 3 3
-- conv5_3: 512 512 3 3
-- fc6: 1 1 25088 4096
-- fc7: 1 1 4096 4096
-- fc8: 1 1 4096 1000

-- %%
model:get(1).weight
-- Out:
-- (1,1,.,.) =
--   0.4295  0.3735 -0.0614
--   0.2748  0.0387 -0.3672
--  -0.0575 -0.2622 -0.3501
--
-- (2,1,.,.) =
--   0.1173  0.1621  0.1357
--   0.1484  0.2023  0.1617
--   0.1293  0.1716  0.1387
--
-- (3,1,.,.) =
--   0.0340  0.0017 -0.1157
--   0.1616  0.1564 -0.0899
--   0.0129  0.0001 -0.1253
--
-- (4,1,.,.) =
--   0.3542  0.2787  0.3017
--   0.0978 -0.3624 -0.0461
--  -0.0010 -0.4032 -0.1468
--
-- (5,1,.,.) =
--  -0.0866  0.1908  0.1684
--  -0.1865  0.1761  0.1543
--  -0.2396 -0.1416 -0.1027
--
-- (6,1,.,.) =
--   0.2297  0.2394  0.2324
--   0.2514  0.2677  0.2373
--   0.2251  0.2598  0.2205
--
-- (7,1,.,.) =
--   0.0668 -0.1121 -0.1665
--   0.1472 -0.0527 -0.1556
--   0.1520  0.0982  0.0074
--
-- (8,1,.,.) =
--   0.0413  0.1166  0.1031
--  -0.2126 -0.1491  0.0383
--  -0.2132 -0.1857 -0.0016
--
-- (9,1,.,.) =
--   0.1303  0.0959  0.1264
--   0.1114  0.0772  0.0991
--   0.1064  0.1134  0.0944
--
-- (10,1,.,.) =
--   0.0329 -0.0527  0.0159
--   0.1530  0.0980  0.1492
-- ...

-- %%
print(a:siz())
-- Out:
-- [torch.LongStorage of size 0]
